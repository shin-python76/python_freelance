# %%
#課題　偶数・奇数の判定

#入力した数字が

#偶数なら「偶数です」

#奇数なら「奇数です」

#と表示するプログラムを作ってください。

# %%
num = input('数字を入力してください')
num = int(num)

if num % 2 == 0:
  print('偶数です')
else:
  print('奇数です')
# Out:
# 数字を入力してください7
# 奇数です
