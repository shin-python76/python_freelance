# %%
#課題　入力した数字が

#0より大きければ「正の数です」

#0より小さければ「負の数です」

#0なら「0です」
#と表示するプログラムを作ってください。

# %%
num = input('数字を入力してください')
num = int(num)

if num > 0:
  print('正の数です')
elif num < 0:
  print('負の数です')
else:
  print('0です')
# Out:
# 数字を入力してください-2
# 負の数です
