# %%
#課題　名前と年齢を入力して次のように表示してください。
#私は◯◯、◯歳です。

#条件

#input() を使って「名前」と「年齢」を入力

#年齢は数字として扱う（int型に変換）

#最終的に 1 行で表示する

# %%
name = input('名前を入力してください')
age = input('年齢を入力してください')
age = int(age)

print('私は'+ name +'、'+ str(age)+'歳です。')
# Out:
# 名前を入力してくださいシン
# 年齢を入力してください49
# 私はシン、49歳です。
